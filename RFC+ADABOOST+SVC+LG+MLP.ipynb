# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE  # imblearn library can be installed using pip install imblearn
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from imblearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Importing dataset and examining it
dataset = pd.read_csv("Leads X Education.csv")
pd.set_option('display.max_columns', None) # to make sure you can see all the columns in output window
print(dataset.head())
print(dataset.shape)
print(dataset.info())
print(dataset.describe())
# Out:
#                             Prospect ID     Lead Source  Converted  \
# 0  8cc8c611-a219-4f35-ad23-fdfd2656bd8a  Direct Traffic          1
# 1  0cc2df48-7cf4-4e39-9de9-19797f9b38cc  Direct Traffic          0
# 2  3256f628-e534-4826-9d63-4a8b88782852          Google          1
# 3  9fae7df4-169d-489b-afe4-0f3d752542ed          Google          1
# 4  2a369e35-ca95-4ca9-9e4f-9d27175aa320  Organic Search          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0            2                         1532                   2.0
# 1            1                          305                   1.0
# 2            2                         1428                   1.0
# 3            2                         1640                   2.0
# 4            8                         1351                   8.0
#
#        Last Activity Country           Specialization  \
# 0       Email Opened   India  Business Administration
# 1        Unreachable   India    Media and Advertising
# 2  Converted to Lead   India                   Select
# 3       Email Opened   India  Supply Chain Management
# 4       Email Opened   India       Travel and Tourism
#
#   How did you hear about X Education What is your current occupation  \
# 0                             Select                         Student
# 1                      Word Of Mouth                      Unemployed
# 2                              Other                      Unemployed
# 3                      Online Search                      Unemployed
# 4                             Select                      Unemployed
#
#   What matters most to you in choosing a course  \
# 0                       Better Career Prospects
# 1                       Better Career Prospects
# 2                       Better Career Prospects
# 3                       Better Career Prospects
# 4                       Better Career Prospects
#
#                                   Tags      Lead Quality    Lead Profile  \
# 0  Will revert after reading the email          Might be  Potential Lead
# 1                              Ringing          Not Sure          Select
# 2  Will revert after reading the email          Might be          Select
# 3  Will revert after reading the email  Low in Relevance  Potential Lead
# 4  Will revert after reading the email          Might be          Select
#
#   Asymmetrique Activity Index Asymmetrique Profile Index  \
# 0                   02.Medium                    01.High
# 1                   02.Medium                    01.High
# 2                   02.Medium                    01.High
# 3                   02.Medium                    01.High
# 4                   02.Medium                  02.Medium
#
#    Asymmetrique Activity Score  Asymmetrique Profile Score
# 0                         14.0                        20.0
# 1                         13.0                        17.0
# 2                         15.0                        18.0
# 3                         14.0                        20.0
# 4                         15.0                        14.0
# (3474, 19)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3474 entries, 0 to 3473
# Data columns (total 19 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    3474 non-null   object
#  1   Lead Source                                    3474 non-null   object
#  2   Converted                                      3474 non-null   int64
#  3   TotalVisits                                    3474 non-null   int64
#  4   Total Time Spent on Website                    3474 non-null   int64
#  5   Page Views Per Visit                           3474 non-null   float64
#  6   Last Activity                                  3474 non-null   object
#  7   Country                                        3474 non-null   object
#  8   Specialization                                 3474 non-null   object
#  9   How did you hear about X Education             3474 non-null   object
#  10  What is your current occupation                3474 non-null   object
#  11  What matters most to you in choosing a course  3474 non-null   object
#  12  Tags                                           3474 non-null   object
#  13  Lead Quality                                   3474 non-null   object
#  14  Lead Profile                                   3474 non-null   object
#  15  Asymmetrique Activity Index                    1943 non-null   object
#  16  Asymmetrique Profile Index                     1943 non-null   object
#  17  Asymmetrique Activity Score                    1943 non-null   float64
#  18  Asymmetrique Profile Score                     1943 non-null   float64
# dtypes: float64(3), int64(3), object(13)
# memory usage: 515.8+ KB
# None
#          Converted  TotalVisits  Total Time Spent on Website  \
# count  3474.000000  3474.000000                  3474.000000
# mean      0.527058     4.679908                   725.543466
# std       0.499339     5.551996                   559.414885
# min       0.000000     0.000000                     0.000000
# 25%       0.000000     2.000000                   212.000000
# 50%       1.000000     4.000000                   601.000000
# 75%       1.000000     5.000000                  1212.750000
# max       1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           3474.000000                  1943.000000
# mean               3.207562                    14.135358
# std                1.855915                     1.255554
# min                0.000000                     8.000000
# 25%                2.000000                    14.000000
# 50%                3.000000                    14.000000
# 75%                4.000000                    15.000000
# max               16.000000                    18.000000
#
#        Asymmetrique Profile Score
# count                 1943.000000
# mean                    16.990736
# std                      1.901790
# min                     12.000000
# 25%                     15.000000
# 50%                     17.000000
# 75%                     18.000000
# max                     20.000000

# %%
dataset["Asymmetrique Activity Index"]=dataset["Asymmetrique Activity Index"].replace(["01.High", "02.Medium","03.Low"],["High","Medium","Low"])
dataset["Asymmetrique Profile Index"]=dataset["Asymmetrique Profile Index"].replace(["01.High", "02.Medium","03.Low"],["High","Medium","Low"])
#cleaning string values in Asymmetrique Activity Index and Asymmetrique Profile Index

# %%
# Creating a list of Object data type columns
obj_cols = dataset.select_dtypes(np.object).columns.tolist()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# Checking the categorical values in the Object columns
def check_value_counts(col_list):
  for col in col_list:
    print('-----------------------------')
    print(round((dataset[col].value_counts()/dataset.shape[0])*100,2))
    print('-----------------------------')

check_value_counts(obj_cols)
# Out:
# -----------------------------
# 8cc8c611-a219-4f35-ad23-fdfd2656bd8a    0.03
# 06b92b61-bd27-4ecb-84f5-6a38c0082616    0.03
# 59306794-fa88-4bac-91e3-a87d4ecdfb83    0.03
# 92677aef-11cd-411c-b636-f601d673e46c    0.03
# c7cc4b98-b373-48c1-bede-d2c81470f4cc    0.03
#                                         ...
# f9898c5d-ea4d-4d40-a897-0e6a3873653a    0.03
# 216d2ac0-077f-4e65-8c39-598a3282afeb    0.03
# 72fb7233-ba78-4a3d-8c83-07ac1725cc6a    0.03
# be8ed098-5821-4e04-b6c2-dbad5f224943    0.03
# 571b5c8e-a5b2-4d57-8574-f2ffb06fdeff    0.03
# Name: Prospect ID, Length: 3474, dtype: float64
# -----------------------------
# -----------------------------
# Google              39.95
# Direct Traffic      39.44
# Organic Search      17.47
# Referral Sites       1.30
# Olark Chat           1.07
# Reference            0.58
# Social Media         0.06
# WeLearn              0.03
# testone              0.03
# Facebook             0.03
# Welingak Website     0.03
# Press_Release        0.03
# Name: Lead Source, dtype: float64
# -----------------------------
# -----------------------------
# SMS Sent                        38.34
# Email Opened                    35.29
# Page Visited on Website          7.71
# Converted to Lead                4.86
# Olark Chat Conversation          3.37
# Email Bounced                    3.31
# Email Link Clicked               2.33
# Unreachable                      1.73
# Form Submitted on Website        1.50
# Unsubscribed                     0.69
# Had a Phone Conversation         0.63
# Approached upfront               0.09
# Email Received                   0.06
# Visited Booth in Tradeshow       0.03
# View in browser link Clicked     0.03
# Email Marked Spam                0.03
# Name: Last Activity, dtype: float64
# -----------------------------
# -----------------------------
# India                   95.97
# United States            0.92
# United Arab Emirates     0.89
# Singapore                0.43
# Saudi Arabia             0.32
# United Kingdom           0.29
# Hong Kong                0.14
# Bahrain                  0.12
# Australia                0.12
# France                   0.12
# Qatar                    0.09
# Oman                     0.09
# Kuwait                   0.06
# Netherlands              0.06
# South Africa             0.03
# Indonesia                0.03
# Italy                    0.03
# China                    0.03
# Canada                   0.03
# Denmark                  0.03
# Germany                  0.03
# Uganda                   0.03
# Malaysia                 0.03
# Tanzania                 0.03
# Nigeria                  0.03
# Sweden                   0.03
# Ghana                    0.03
# Bangladesh               0.03
# Name: Country, dtype: float64
# -----------------------------
# -----------------------------
# Finance Management                   14.28
# Select                               12.78
# Marketing Management                 12.69
# Human Resource Management            12.46
# Operations Management                 7.25
# Business Administration               6.19
# IT Projects Management                5.61
# Supply Chain Management               5.30
# Banking, Investment And Insurance     5.01
# Travel and Tourism                    3.14
# Media and Advertising                 3.05
# International Business                2.71
# Healthcare Management                 2.33
# Hospitality Management                1.73
# Retail Management                     1.67
# E-COMMERCE                            1.41
# Rural and Agribusiness                1.04
# E-Business                            0.86
# Services Excellence                   0.49
# Name: Specialization, dtype: float64
# -----------------------------
# -----------------------------
# Select                   68.45
# Online Search            12.72
# Word Of Mouth             5.56
# Student of SomeSchool     5.09
# Other                     2.88
# Multiple Sources          2.27
# Social Media              1.15
# Advertisements            1.12
# Email                     0.52
# SMS                       0.23
# Name: How did you hear about X Education, dtype: float64
# -----------------------------
# -----------------------------
# Unemployed              82.70
# Working Professional    13.04
# Student                  3.57
# Other                    0.37
# Housewife                0.20
# Businessman              0.12
# Name: What is your current occupation, dtype: float64
# -----------------------------
# -----------------------------
# Better Career Prospects    99.97
# Other                       0.03
# Name: What matters most to you in choosing a course, dtype: float64
# -----------------------------
# -----------------------------
# Will revert after reading the email                  43.32
# Ringing                                              16.44
# Already a student                                     7.77
# Interested in other courses                           6.16
# Busy                                                  4.72
# switched off                                          4.35
# Closed by Horizzon                                    4.20
# Not doing further education                           3.02
# Lost to EINS                                          1.76
# Graduation in progress                                1.73
# Interested  in full time MBA                          1.67
# invalid number                                        1.24
# wrong number given                                    0.95
# Diploma holder (Not Eligible)                         0.92
# number not provided                                   0.58
# opp hangup                                            0.52
# In confusion whether part time or DLP                 0.12
# Still Thinking                                        0.12
# Interested in Next batch                              0.12
# in touch with EINS                                    0.09
# Want to take admission but has financial problems     0.09
# Lost to Others                                        0.06
# Shall take in the next coming month                   0.03
# Recognition issue (DEC approval)                      0.03
# Lateral student                                       0.03
# Name: Tags, dtype: float64
# -----------------------------
# -----------------------------
# Might be             34.54
# Not Sure             28.01
# Worst                13.76
# Low in Relevance     12.35
# High in Relevance    11.34
# Name: Lead Quality, dtype: float64
# -----------------------------
# -----------------------------
# Select                         53.83
# Potential Lead                 29.02
# Other Leads                    11.46
# Student of SomeSchool           4.86
# Dual Specialization Student     0.49
# Lateral Student                 0.35
# Name: Lead Profile, dtype: float64
# -----------------------------
# -----------------------------
# Medium    45.83
# High       5.81
# Low        4.29
# Name: Asymmetrique Activity Index, dtype: float64
# -----------------------------
# -----------------------------
# High      34.20
# Medium    21.45
# Low        0.29
# Name: Asymmetrique Profile Index, dtype: float64
# -----------------------------

# %%
# Dropping columns which do not add value to the dataset
dataset = dataset.drop(columns=['Prospect ID','How did you hear about X Education','Country','What matters most to you in choosing a course'], axis=1)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3474 entries, 0 to 3473
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Lead Source                      3474 non-null   object
#  1   Converted                        3474 non-null   int64
#  2   TotalVisits                      3474 non-null   int64
#  3   Total Time Spent on Website      3474 non-null   int64
#  4   Page Views Per Visit             3474 non-null   float64
#  5   Last Activity                    3474 non-null   object
#  6   Specialization                   3474 non-null   object
#  7   What is your current occupation  3474 non-null   object
#  8   Tags                             3474 non-null   object
#  9   Lead Quality                     3474 non-null   object
#  10  Lead Profile                     3474 non-null   object
#  11  Asymmetrique Activity Index      1943 non-null   object
#  12  Asymmetrique Profile Index       1943 non-null   object
#  13  Asymmetrique Activity Score      1943 non-null   float64
#  14  Asymmetrique Profile Score       1943 non-null   float64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 407.2+ KB

# %%
# Specialization columns has value as 'Select', we can consider this error as 'Other' category
dataset['Specialization'] = dataset['Specialization'].apply(lambda x:'Other' if x=='Select' else x)
dataset['Lead Profile'] = dataset['Lead Profile'].apply(lambda x:'Other' if x=='Select' else x)
dataset['Specialization'].value_counts()
# Out:
# Finance Management                   496
# Other                                444
# Marketing Management                 441
# Human Resource Management            433
# Operations Management                252
# Business Administration              215
# IT Projects Management               195
# Supply Chain Management              184
# Banking, Investment And Insurance    174
# Travel and Tourism                   109
# Media and Advertising                106
# International Business                94
# Healthcare Management                 81
# Hospitality Management                60
# Retail Management                     58
# E-COMMERCE                            49
# Rural and Agribusiness                36
# E-Business                            30
# Services Excellence                   17
# Name: Specialization, dtype: int64

# %%
# Creating a list of object type columns
obj_cols = dataset.select_dtypes(np.object).columns.tolist()
obj_cols
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ['Lead Source',
#  'Last Activity',
#  'Specialization',
#  'What is your current occupation',
#  'Tags',
#  'Lead Quality',
#  'Lead Profile',
#  'Asymmetrique Activity Index',
#  'Asymmetrique Profile Index']

# %%
dataset = pd.get_dummies(data=dataset, columns=['Lead Source', 'Last Activity','Specialization','Tags','What is your current occupation'])

# %%
# Converting Categorical features into Numerical features
dataset['Lead Quality'] = dataset['Lead Quality'].map({'Might be':0,'Not Sure':1,'Worst':2,'Low in Relevance':3,'High in Relevance':4})
dataset['Lead Profile'] = dataset['Lead Profile'].map({'Other':0, 'Potential Lead':1, 'Other Leads':2, 'Student of SomeSchool': 3, 'Dual Specialization Student':4, 'Lateral Student':5})
dataset['Asymmetrique Activity Index'] = dataset['Asymmetrique Activity Index'].map({'Low':0, 'Medium':1, 'High':2})
dataset['Asymmetrique Profile Index'] = dataset['Asymmetrique Profile Index'].map({'Low':0, 'Medium':1, 'High':2})

                                           
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3474 entries, 0 to 3473
# Data columns (total 88 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Converted                                               3474 non-null   int64
#  1   TotalVisits                                             3474 non-null   int64
#  2   Total Time Spent on Website                             3474 non-null   int64
#  3   Page Views Per Visit                                    3474 non-null   float64
#  4   Lead Quality                                            3474 non-null   int64
#  5   Lead Profile                                            3474 non-null   int64
#  6   Asymmetrique Activity Index                             1943 non-null   float64
#  7   Asymmetrique Profile Index                              1943 non-null   float64
#  8   Asymmetrique Activity Score                             1943 non-null   float64
#  9   Asymmetrique Profile Score                              1943 non-null   float64
#  10  Lead Source_Direct Traffic                              3474 non-null   uint8
#  11  Lead Source_Facebook                                    3474 non-null   uint8
#  12  Lead Source_Google                                      3474 non-null   uint8
#  13  Lead Source_Olark Chat                                  3474 non-null   uint8
#  14  Lead Source_Organic Search                              3474 non-null   uint8
#  15  Lead Source_Press_Release                               3474 non-null   uint8
#  16  Lead Source_Reference                                   3474 non-null   uint8
#  17  Lead Source_Referral Sites                              3474 non-null   uint8
#  18  Lead Source_Social Media                                3474 non-null   uint8
#  19  Lead Source_WeLearn                                     3474 non-null   uint8
#  20  Lead Source_Welingak Website                            3474 non-null   uint8
#  21  Lead Source_testone                                     3474 non-null   uint8
#  22  Last Activity_Approached upfront                        3474 non-null   uint8
#  23  Last Activity_Converted to Lead                         3474 non-null   uint8
#  24  Last Activity_Email Bounced                             3474 non-null   uint8
#  25  Last Activity_Email Link Clicked                        3474 non-null   uint8
#  26  Last Activity_Email Marked Spam                         3474 non-null   uint8
#  27  Last Activity_Email Opened                              3474 non-null   uint8
#  28  Last Activity_Email Received                            3474 non-null   uint8
#  29  Last Activity_Form Submitted on Website                 3474 non-null   uint8
#  30  Last Activity_Had a Phone Conversation                  3474 non-null   uint8
#  31  Last Activity_Olark Chat Conversation                   3474 non-null   uint8
#  32  Last Activity_Page Visited on Website                   3474 non-null   uint8
#  33  Last Activity_SMS Sent                                  3474 non-null   uint8
#  34  Last Activity_Unreachable                               3474 non-null   uint8
#  35  Last Activity_Unsubscribed                              3474 non-null   uint8
#  36  Last Activity_View in browser link Clicked              3474 non-null   uint8
#  37  Last Activity_Visited Booth in Tradeshow                3474 non-null   uint8
#  38  Specialization_Banking, Investment And Insurance        3474 non-null   uint8
#  39  Specialization_Business Administration                  3474 non-null   uint8
#  40  Specialization_E-Business                               3474 non-null   uint8
#  41  Specialization_E-COMMERCE                               3474 non-null   uint8
#  42  Specialization_Finance Management                       3474 non-null   uint8
#  43  Specialization_Healthcare Management                    3474 non-null   uint8
#  44  Specialization_Hospitality Management                   3474 non-null   uint8
#  45  Specialization_Human Resource Management                3474 non-null   uint8
#  46  Specialization_IT Projects Management                   3474 non-null   uint8
#  47  Specialization_International Business                   3474 non-null   uint8
#  48  Specialization_Marketing Management                     3474 non-null   uint8
#  49  Specialization_Media and Advertising                    3474 non-null   uint8
#  50  Specialization_Operations Management                    3474 non-null   uint8
#  51  Specialization_Other                                    3474 non-null   uint8
#  52  Specialization_Retail Management                        3474 non-null   uint8
#  53  Specialization_Rural and Agribusiness                   3474 non-null   uint8
#  54  Specialization_Services Excellence                      3474 non-null   uint8
#  55  Specialization_Supply Chain Management                  3474 non-null   uint8
#  56  Specialization_Travel and Tourism                       3474 non-null   uint8
#  57  Tags_Already a student                                  3474 non-null   uint8
#  58  Tags_Busy                                               3474 non-null   uint8
#  59  Tags_Closed by Horizzon                                 3474 non-null   uint8
#  60  Tags_Diploma holder (Not Eligible)                      3474 non-null   uint8
#  61  Tags_Graduation in progress                             3474 non-null   uint8
#  62  Tags_In confusion whether part time or DLP              3474 non-null   uint8
#  63  Tags_Interested  in full time MBA                       3474 non-null   uint8
#  64  Tags_Interested in Next batch                           3474 non-null   uint8
#  65  Tags_Interested in other courses                        3474 non-null   uint8
#  66  Tags_Lateral student                                    3474 non-null   uint8
#  67  Tags_Lost to EINS                                       3474 non-null   uint8
#  68  Tags_Lost to Others                                     3474 non-null   uint8
#  69  Tags_Not doing further education                        3474 non-null   uint8
#  70  Tags_Recognition issue (DEC approval)                   3474 non-null   uint8
#  71  Tags_Ringing                                            3474 non-null   uint8
#  72  Tags_Shall take in the next coming month                3474 non-null   uint8
#  73  Tags_Still Thinking                                     3474 non-null   uint8
#  74  Tags_Want to take admission but has financial problems  3474 non-null   uint8
#  75  Tags_Will revert after reading the email                3474 non-null   uint8
#  76  Tags_in touch with EINS                                 3474 non-null   uint8
#  77  Tags_invalid number                                     3474 non-null   uint8
#  78  Tags_number not provided                                3474 non-null   uint8
#  79  Tags_opp hangup                                         3474 non-null   uint8
#  80  Tags_switched off                                       3474 non-null   uint8
#  81  Tags_wrong number given                                 3474 non-null   uint8
#  82  What is your current occupation_Businessman             3474 non-null   uint8
#  83  What is your current occupation_Housewife               3474 non-null   uint8
#  84  What is your current occupation_Other                   3474 non-null   uint8
#  85  What is your current occupation_Student                 3474 non-null   uint8
#  86  What is your current occupation_Unemployed              3474 non-null   uint8
#  87  What is your current occupation_Working Professional    3474 non-null   uint8
# dtypes: float64(5), int64(5), uint8(78)
# memory usage: 536.2 KB
# None

# %%
dataset.fillna(0, inplace=True)#Missing values replaced with 0
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3474 entries, 0 to 3473
# Data columns (total 88 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Converted                                               3474 non-null   int64
#  1   TotalVisits                                             3474 non-null   int64
#  2   Total Time Spent on Website                             3474 non-null   int64
#  3   Page Views Per Visit                                    3474 non-null   float64
#  4   Lead Quality                                            3474 non-null   int64
#  5   Lead Profile                                            3474 non-null   int64
#  6   Asymmetrique Activity Index                             3474 non-null   float64
#  7   Asymmetrique Profile Index                              3474 non-null   float64
#  8   Asymmetrique Activity Score                             3474 non-null   float64
#  9   Asymmetrique Profile Score                              3474 non-null   float64
#  10  Lead Source_Direct Traffic                              3474 non-null   uint8
#  11  Lead Source_Facebook                                    3474 non-null   uint8
#  12  Lead Source_Google                                      3474 non-null   uint8
#  13  Lead Source_Olark Chat                                  3474 non-null   uint8
#  14  Lead Source_Organic Search                              3474 non-null   uint8
#  15  Lead Source_Press_Release                               3474 non-null   uint8
#  16  Lead Source_Reference                                   3474 non-null   uint8
#  17  Lead Source_Referral Sites                              3474 non-null   uint8
#  18  Lead Source_Social Media                                3474 non-null   uint8
#  19  Lead Source_WeLearn                                     3474 non-null   uint8
#  20  Lead Source_Welingak Website                            3474 non-null   uint8
#  21  Lead Source_testone                                     3474 non-null   uint8
#  22  Last Activity_Approached upfront                        3474 non-null   uint8
#  23  Last Activity_Converted to Lead                         3474 non-null   uint8
#  24  Last Activity_Email Bounced                             3474 non-null   uint8
#  25  Last Activity_Email Link Clicked                        3474 non-null   uint8
#  26  Last Activity_Email Marked Spam                         3474 non-null   uint8
#  27  Last Activity_Email Opened                              3474 non-null   uint8
#  28  Last Activity_Email Received                            3474 non-null   uint8
#  29  Last Activity_Form Submitted on Website                 3474 non-null   uint8
#  30  Last Activity_Had a Phone Conversation                  3474 non-null   uint8
#  31  Last Activity_Olark Chat Conversation                   3474 non-null   uint8
#  32  Last Activity_Page Visited on Website                   3474 non-null   uint8
#  33  Last Activity_SMS Sent                                  3474 non-null   uint8
#  34  Last Activity_Unreachable                               3474 non-null   uint8
#  35  Last Activity_Unsubscribed                              3474 non-null   uint8
#  36  Last Activity_View in browser link Clicked              3474 non-null   uint8
#  37  Last Activity_Visited Booth in Tradeshow                3474 non-null   uint8
#  38  Specialization_Banking, Investment And Insurance        3474 non-null   uint8
#  39  Specialization_Business Administration                  3474 non-null   uint8
#  40  Specialization_E-Business                               3474 non-null   uint8
#  41  Specialization_E-COMMERCE                               3474 non-null   uint8
#  42  Specialization_Finance Management                       3474 non-null   uint8
#  43  Specialization_Healthcare Management                    3474 non-null   uint8
#  44  Specialization_Hospitality Management                   3474 non-null   uint8
#  45  Specialization_Human Resource Management                3474 non-null   uint8
#  46  Specialization_IT Projects Management                   3474 non-null   uint8
#  47  Specialization_International Business                   3474 non-null   uint8
#  48  Specialization_Marketing Management                     3474 non-null   uint8
#  49  Specialization_Media and Advertising                    3474 non-null   uint8
#  50  Specialization_Operations Management                    3474 non-null   uint8
#  51  Specialization_Other                                    3474 non-null   uint8
#  52  Specialization_Retail Management                        3474 non-null   uint8
#  53  Specialization_Rural and Agribusiness                   3474 non-null   uint8
#  54  Specialization_Services Excellence                      3474 non-null   uint8
#  55  Specialization_Supply Chain Management                  3474 non-null   uint8
#  56  Specialization_Travel and Tourism                       3474 non-null   uint8
#  57  Tags_Already a student                                  3474 non-null   uint8
#  58  Tags_Busy                                               3474 non-null   uint8
#  59  Tags_Closed by Horizzon                                 3474 non-null   uint8
#  60  Tags_Diploma holder (Not Eligible)                      3474 non-null   uint8
#  61  Tags_Graduation in progress                             3474 non-null   uint8
#  62  Tags_In confusion whether part time or DLP              3474 non-null   uint8
#  63  Tags_Interested  in full time MBA                       3474 non-null   uint8
#  64  Tags_Interested in Next batch                           3474 non-null   uint8
#  65  Tags_Interested in other courses                        3474 non-null   uint8
#  66  Tags_Lateral student                                    3474 non-null   uint8
#  67  Tags_Lost to EINS                                       3474 non-null   uint8
#  68  Tags_Lost to Others                                     3474 non-null   uint8
#  69  Tags_Not doing further education                        3474 non-null   uint8
#  70  Tags_Recognition issue (DEC approval)                   3474 non-null   uint8
#  71  Tags_Ringing                                            3474 non-null   uint8
#  72  Tags_Shall take in the next coming month                3474 non-null   uint8
#  73  Tags_Still Thinking                                     3474 non-null   uint8
#  74  Tags_Want to take admission but has financial problems  3474 non-null   uint8
#  75  Tags_Will revert after reading the email                3474 non-null   uint8
#  76  Tags_in touch with EINS                                 3474 non-null   uint8
#  77  Tags_invalid number                                     3474 non-null   uint8
#  78  Tags_number not provided                                3474 non-null   uint8
#  79  Tags_opp hangup                                         3474 non-null   uint8
#  80  Tags_switched off                                       3474 non-null   uint8
#  81  Tags_wrong number given                                 3474 non-null   uint8
#  82  What is your current occupation_Businessman             3474 non-null   uint8
#  83  What is your current occupation_Housewife               3474 non-null   uint8
#  84  What is your current occupation_Other                   3474 non-null   uint8
#  85  What is your current occupation_Student                 3474 non-null   uint8
#  86  What is your current occupation_Unemployed              3474 non-null   uint8
#  87  What is your current occupation_Working Professional    3474 non-null   uint8
# dtypes: float64(5), int64(5), uint8(78)
# memory usage: 536.2 KB

# %%
# Dividing dataset into label and feature sets
X = dataset.drop(['Converted'], axis = 1) # Features
Y = dataset['Converted'] # Labels
print(type(X))
print(type(Y))
print(X.shape)
print(Y.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (3474, 87)
# (3474,)

# %%
# Normalizing numerical features so that each feature has mean 0 and variance 1
feature_scaler = StandardScaler()
X_scaled = feature_scaler.fit_transform(X)

# Implementing Random Forest Classifier
# Tuning the random forest parameter 'n_estimators' and implementing cross-validation using Grid Search
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', RandomForestClassifier(criterion='entropy', max_features='auto', random_state=1) )
    ])
grid_param = {'classification__n_estimators': [250,300,350,400,450]}

gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

"""
In the above GridSearchCV(), scoring parameter should be set as follows:
scoring = 'accuracy' when you want to maximize prediction accuracy
scoring = 'recall' when you want to minimize false negatives
scoring = 'precision' when you want to minimize false positives
scoring = 'f1' when you want to balance false positives and false negatives (place equal emphasis on minimizing both)
"""

gd_sr.fit(X_scaled, Y)

best_parameters = gd_sr.best_params_
print(best_parameters)

best_result = gd_sr.best_score_ # Mean cross-validated score of the best_estimator
print(best_result)

featimp = pd.Series(gd_sr.best_estimator_.named_steps["classification"].feature_importances_, index=list(X)).sort_values(ascending=False) # Getting feature importances list for the best model
print(featimp)

# Selecting features with higher sifnificance and redefining feature set
X_ = dataset[['Tags_Will revert after reading the email','Total Time Spent on Website','Lead Quality','Tags_Ringing','Tags_Already a student']]

feature_scaler = StandardScaler()
X_scaled_ = feature_scaler.fit_transform(X_)

# Tuning the random forest parameter 'n_estimators' and implementing cross-validation using Grid Search
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', RandomForestClassifier(criterion='entropy', max_features='auto', random_state=1) )
    ])
grid_param = {'classification__n_estimators': [450]}

gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

"""
In the above GridSearchCV(), scoring parameter should be set as follows:
scoring = 'accuracy' when you want to maximize prediction accuracy
scoring = 'recall' when you want to minimize false negatives
scoring = 'precision' when you want to minimize false positives
scoring = 'f1' when you want to balance false positives and false negatives (place equal emphasis on minimizing both)
"""

gd_sr.fit(X_scaled_, Y)

best_parameters = gd_sr.best_params_
print(best_parameters)

best_result = gd_sr.best_score_ # Mean cross-validated score of the best_estimator
print(best_result)

print(pd.DataFrame.from_dict(gd_sr.cv_results_)) # Use this line of code if you want to look at cross-validation results for each split

################################################################################
# Out:
# {'classification__n_estimators': 450}
# 0.9557615282678935
# Tags_Will revert after reading the email      2.713208e-01
# Total Time Spent on Website                   1.247514e-01
# Lead Quality                                  8.340102e-02
# Tags_Ringing                                  7.295988e-02
# Tags_Already a student                        3.256148e-02
#                                                   ...
# Last Activity_View in browser link Clicked    6.159576e-06
# Last Activity_Email Marked Spam               6.085705e-06
# Last Activity_Email Received                  3.244627e-06
# Lead Source_WeLearn                           8.860774e-08
# Lead Source_testone                           0.000000e+00
# Length: 87, dtype: float64
# {'classification__n_estimators': 450}
# 0.8934724021381456
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.667948       0.02665         0.099557        0.003081
#
#   param_classification__n_estimators                                 params  \
# 0                                450  {'classification__n_estimators': 450}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.945504           0.879781           0.877049            0.86612
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.898907         0.893472        0.028079                1

# %%
# Implementing AdaBoost
# Tuning the AdaBoost parameter 'n_estimators' and implementing cross-validation using Grid Search
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', AdaBoostClassifier(random_state=1))
    ])
grid_param = {'classification__n_estimators': [1,2,3,4,5,10,20,30,40,50,100]}

gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

"""
In the above GridSearchCV(), scoring parameter should be set as follows:
scoring = 'accuracy' when you want to maximize prediction accuracy
scoring = 'recall' when you want to minimize false negatives
scoring = 'precision' when you want to minimize false positives
scoring = 'f1' when you want to balance false positives and false negatives (place equal emphasis on minimizing both)
"""

gd_sr.fit(X_scaled, Y)

best_parameters = gd_sr.best_params_
print(best_parameters)

best_result = gd_sr.best_score_ # Mean cross-validated score of the best_estimator
print(best_result)

featimp = pd.Series(gd_sr.best_estimator_.named_steps["classification"].feature_importances_, index=list(X)).sort_values(ascending=False) # Getting feature importances list for the best model
print(featimp)
# Out:
# {'classification__n_estimators': 100}
# 0.9541281398430638
# Total Time Spent on Website              0.33
# Page Views Per Visit                     0.09
# Lead Quality                             0.06
# Asymmetrique Activity Score              0.06
# TotalVisits                              0.05
#                                          ...
# Specialization_Services Excellence       0.00
# Last Activity_Email Link Clicked         0.00
# Specialization_Travel and Tourism        0.00
# Last Activity_Converted to Lead          0.00
# Specialization_Hospitality Management    0.00
# Length: 87, dtype: float64

# %%
# # ##################################################################################
# Implementing Support Vector Classifier
# Tuning the kernel parameter and implementing cross-validation using Grid Search
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', SVC(random_state=1) )
    ])
grid_param = {'classification__kernel': ['linear','poly', 'rbf', 'sigmoid'], 'classification__C': [.001,.01,.1,1,10,100]}

gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

"""
In the above GridSearchCV(), scoring parameter should be set as follows:
scoring = 'accuracy' when you want to maximize prediction accuracy
scoring = 'recall' when you want to minimize false negatives
scoring = 'precision' when you want to minimize false positives
scoring = 'f1' when you want to balance false positives and false negatives (place equal emphasis on minimizing both)
"""

gd_sr.fit(X_scaled, Y)

best_parameters = gd_sr.best_params_
print(best_parameters)

best_result = gd_sr.best_score_ # Mean cross-validated score of the best_estimator
print(best_result)

##################################################################################
# Implementing Logistic Regression
# Tuning eta0, max_iter, alpha, and l1 ratio parameters and implementing cross-validation using Grid Search
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', SGDClassifier(loss = 'log', penalty = 'elasticnet', random_state = 1))
    ])
grid_param = {'classification__eta0': [.001,.01,.1,1,10,100], 'classification__max_iter' : [100,500,1000], 'classification__alpha': [.001, .01,.1, 1,10,100], 'classification__l1_ratio': [0,0.3,0.5,0.7,1]}

gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

"""
In the above GridSearchCV(), scoring parameter should be set as follows:
scoring = 'accuracy' when you want to maximize prediction accuracy
scoring = 'recall' when you want to minimize false negatives
scoring = 'precision' when you want to minimize false positives
scoring = 'f1' when you want to balance false positives and false negatives (place equal emphasis on minimizing both)
"""

gd_sr.fit(X_scaled, Y)

best_parameters = gd_sr.best_params_
print(best_parameters)

best_result = gd_sr.best_score_ # Mean cross-validated score of the best_estimator
print(best_result)

# Implementing Multi-layer Perceptron (MLP)
# Tuning the MLP hyperparameters and implementing cross-validation using Grid Search
model = Pipeline([
        ('balancing', SMOTE(random_state = 101)),
        ('classification', MLPClassifier(hidden_layer_sizes = (50,), random_state=1)) # hidden_layer_sizes determines the number of layers and the number of units within those layers. It can be a hyperparameter
    ])
grid_param = {'classification__activation': ['logistic', 'tanh', 'relu'], 'classification__learning_rate_init': [.001,.01,.1,1,10,100], 'classification__max_iter' : [100,500,1000]}

gd_sr = GridSearchCV(estimator=model, param_grid=grid_param, scoring='recall', cv=5)

"""
In the above GridSearchCV(), scoring parameter should be set as follows:
scoring = 'accuracy' when you want to maximize prediction accuracy
scoring = 'recall' when you want to minimize false negatives
scoring = 'precision' when you want to minimize false positives
scoring = 'f1' when you want to balance false positives and false negatives (place equal emphasis on minimizing both)
"""

gd_sr.fit(X_scaled, Y)

best_parameters = gd_sr.best_params_
print(best_parameters)

best_result = gd_sr.best_score_ # Mean cross-validated score of the best_estimator
print(best_result)
# Out:
# {'classification__C': 0.1, 'classification__kernel': 'poly'}
# 0.9819776358303182
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# {'classification__alpha': 1, 'classification__eta0': 0.001, 'classification__l1_ratio': 0.5, 'classification__max_iter': 100}
# 1.0
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# {'classification__activation': 'logistic', 'classification__learning_rate_init': 1, 'classification__max_iter': 100}
# 0.9552225249772934
